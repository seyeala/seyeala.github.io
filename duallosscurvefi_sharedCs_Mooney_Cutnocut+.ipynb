# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

# %%
from google.colab import drive
drive.mount('/content/drive')
foldername='otest'
filenamecut='cut+.csv'
filenamenocut='nocut+.csv'
filenamecutpath='/content/drive/MyDrive/'+foldername+'/'+filenamecut
filenamenocutpath='/content/drive/MyDrive/'+foldername+'/'+filenamenocut
numberofbrakpoints=1

# %%
loading_or_unloading=1
epch=10000

# %%
datacut = pd.read_csv(
    filenamecutpath,
    names=["A", "B"])

datacut.head()

# %%
datanocut = pd.read_csv(
    filenamenocutpath,
    names=["A", "B"])

datanocut.head()

# %%
all_datacut = datacut.copy()

inputscut = all_datacut.pop('A')
labelscut = all_datacut.pop('B')

# %%
all_datanocut = datanocut.copy()

inputsnocut = all_datanocut.pop('A')
labelsnocut = all_datanocut.pop('B')

# %%
factor=1000000
area= 3e-6
x_datacut=inputscut.to_numpy(dtype=np.float32)
y_datacut=labelscut.to_numpy(dtype=np.float32)/factor

y_datacut=y_datacut-y_datacut[0]

x_datanocut=inputsnocut.to_numpy(dtype=np.float32)
y_datanocut=labelsnocut.to_numpy(dtype=np.float32)/factor

y_datanocut=y_datanocut-y_datanocut[0]

y_datacut = (y_datacut)/area

# For y_datanocut
y_datanocut = (y_datanocut )/area

# %%
y_datacut

# %%
# 1. Define the Shared Coefficient c
class SharedCoefficientLayer(tf.keras.layers.Layer):
    def __init__(self, size, initial_value=None, **kwargs):
        super(SharedCoefficientLayer, self).__init__(**kwargs)
        self.size = size
        self.initial_value = initial_value

    def build(self, input_shape):
        if self.initial_value is not None:
            initializer = tf.keras.initializers.Constant(self.initial_value)
        else:
            initializer = 'uniform'

        self.c = self.add_weight(name='c',
                                 shape=(self.size,),
                                 initializer=initializer,
                                 trainable=True)
        super(SharedCoefficientLayer, self).build(input_shape)

    def call(self, inputs):
        return self.c


# 2. Modify the DualPolynomialLayer to accept external coefficients
class DualPolynomialLayerModified(tf.keras.layers.Layer):
    def __init__(self, power, h, **kwargs):
        super(DualPolynomialLayerModified, self).__init__(**kwargs)
        self.power = power
        self.h = tf.constant(h, dtype=tf.float32)  # Convert to a constant tensor

    def call(self, inputs, **kwargs):
        x, c = inputs

        # Calculate the polynomial terms for each power
        poly_terms = [tf.math.pow(x, p) for p in self.power]
        poly_tensor = tf.stack(poly_terms, axis=-1)  # This creates a tensor with shape (batch_size, len(self.power))

        # Perform matrix multiplication with h and c
        # The resulting shape will be (batch_size, len(self.power), c.shape[-1])
        output_terms = tf.matmul(poly_tensor, self.h)

        # Now, sum along the last dimension after multiplying with c
        outputs = tf.reduce_sum(output_terms * c, axis=-1)

        return outputs



# 3. Construct the Model with Shared Coefficients
import tensorflow as tf



def get_dimensions(matrix):
    rows = len(matrix)
    cols = len(matrix[0]) if rows > 0 else 0
    return (rows, cols)
# Modify the build_dual_polynomial_model function


def build_dual_polynomial_model(powers, h1, h2):
    # Ensure the powers argument contains the required sublists
    if 'powers1' not in powers or 'powers2' not in powers:
        raise ValueError("The 'powers' argument must contain 'powers1' and 'powers2' sublists.")

    # Create the model's input layers
    inputs1 = tf.keras.Input(shape=(1,), name='input_1')
    inputs2 = tf.keras.Input(shape=(1,), name='input_2')

    rowh1,colh1=get_dimensions(h1)
    rowh2,colh2=get_dimensions(h2)
    if colh1!=colh2:
        raise ValueError("Share C values dont match")


    # Shared coefficients layer
    initial_c_values = [0.5, 0.5]
    shared_c_layer = SharedCoefficientLayer(size=colh1, initial_value=initial_c_values)
    shared_c = shared_c_layer(inputs1)
    # First polynomial layer with h1 matrix
    layer1 = DualPolynomialLayerModified(power=powers['powers1'], h=h1)
    outputs1 = layer1([inputs1, shared_c])

    # Second polynomial layer with h2 matrix
    layer2 = DualPolynomialLayerModified(power=powers['powers2'], h=h2)
    outputs2 = layer2([inputs2, shared_c])

    # Build and return the model
    model = tf.keras.Model(inputs=[inputs1, inputs2], outputs={'output_1': outputs1, 'output_2': outputs2})
    return model





# 4. Design the Combined Loss Function
# Assuming mean squared error for both, adjust as needed
def combined_loss(y_true, y_pred):
    #print("Shape of y_true:", tf.shape(y_true))
    #print("Shape of y_pred:", tf.shape(y_pred))

    loss1 = tf.keras.losses.MSE(y_true[0], y_pred[0])
    loss2 = tf.keras.losses.MSE(y_true[1], y_pred[1])
    return loss1 + loss2

powers_dict = {'powers1': [2,-2,2,-4], 'powers2': [1, 2]}
h_matrix1 = [[2, 0], [-2, 0], [0, 2],[0, -4]]
h_matrix2 =[[2, 0], [0, -1]]  # or any other matrix you'd like
model = build_dual_polynomial_model(powers_dict, h_matrix1, h_matrix2)

# %%
# 1. Define the Shared Coefficient c
class SharedCoefficientLayer(tf.keras.layers.Layer):
    def __init__(self, size, initial_value=None, **kwargs):
        super(SharedCoefficientLayer, self).__init__(**kwargs)
        self.size = size
        self.initial_value = initial_value

    def build(self, input_shape):
        if self.initial_value is not None:
            initializer = tf.keras.initializers.Constant(self.initial_value)
        else:
            initializer = 'uniform'

        self.c = self.add_weight(name='c',
                                 shape=(self.size,),
                                 initializer=initializer,
                                 trainable=True)
        super(SharedCoefficientLayer, self).build(input_shape)

    def call(self, inputs):
        return self.c


# 2. Modify the DualPolynomialLayer to accept external coefficients
class DualPolynomialLayerModified(tf.keras.layers.Layer):
    def __init__(self, power, h, **kwargs):
        super(DualPolynomialLayerModified, self).__init__(**kwargs)
        self.power = power
        self.h = tf.constant(h, dtype=tf.float32)  # Convert to a constant tensor

    def call(self, inputs, **kwargs):
        x, c = inputs

        # Calculate the polynomial terms for each power
        poly_terms = [tf.math.pow(x, p) for p in self.power]
        poly_tensor = tf.stack(poly_terms, axis=-1)  # This creates a tensor with shape (batch_size, len(self.power))

        # Perform matrix multiplication with h and c
        # The resulting shape will be (batch_size, len(self.power), c.shape[-1])
        output_terms = tf.matmul(poly_tensor, self.h)

        # Now, sum along the last dimension after multiplying with c
        outputs = tf.reduce_sum(output_terms * c, axis=-1)

        return outputs



# 3. Construct the Model with Shared Coefficients
import tensorflow as tf



def get_dimensions(matrix):
    rows = len(matrix)
    cols = len(matrix[0]) if rows > 0 else 0
    return (rows, cols)
# Modify the build_dual_polynomial_model function

# Add this function to your code
def high_temperature_sigmoid(x, k=100):
    return 1.0 / (1.0 + tf.exp(-k * x))

# Modify the DualPolynomialLayer to accept external coefficients
class DualPolynomialLayerModified(tf.keras.layers.Layer):
    def __init__(self, power, h, **kwargs):
        super(DualPolynomialLayerModified, self).__init__(**kwargs)
        self.power = power
        self.h = tf.constant(h, dtype=tf.float32)  # Convert to a constant tensor

    def build(self, input_shape):
        self.breakx = self.add_weight(name='breakx',
                                      shape=(1,),
                                      initializer=tf.keras.initializers.Constant(240),
                                      trainable=True)

        self.breaky = self.add_weight(name='breaky',
                                      shape=(1,),
                                      initializer=tf.keras.initializers.Constant(-0.15),
                                      trainable=True)
        super(DualPolynomialLayerModified, self).build(input_shape)

    def call(self, inputs, **kwargs):
        x, c = inputs

        # Calculate the polynomial terms for each power
        #scaled_x = x / (self.breakx + 1e-7)
        scaled_x = x
        poly_terms = [tf.math.pow(scaled_x, p) for p in self.power]
        poly_tensor = tf.stack(poly_terms, axis=-1)

        # Perform matrix multiplication with h and c
        output_terms = tf.matmul(poly_tensor, self.h)

        # Now, sum along the last dimension after multiplying with c
        poly_output = tf.reduce_sum(output_terms * c, axis=-1) + self.breaky

        # Apply the sigmoid-based condsitioning
        sigmoid_term = high_temperature_sigmoid(x - self.breakx)
        outputs = poly_output * sigmoid_term + self.breaky * (1.0 - sigmoid_term)

        return outputs




# 4. Design the Combined Loss Function
# Assuming mean squared error for both, adjust as needed
def combined_loss(y_true, y_pred):
    #print("Shape of y_true:", tf.shape(y_true))
    #print("Shape of y_pred:", tf.shape(y_pred))

    loss1 = tf.keras.losses.MSE(y_true[0], y_pred[0])
    loss2 = tf.keras.losses.MSE(y_true[1], y_pred[1])
    return loss1 + loss2

powers_dict = {'powers1': [2,-2,2,-4], 'powers2': [1, 2]}
h_matrix1 = [[2, 0], [-2, 0], [0, 2],[0, -4]]
h_matrix2 =[[2, 0], [0, -1]]  # or any other matrix you'd like
model = build_dual_polynomial_model(powers_dict, h_matrix1, h_matrix2)

# %%
# 1. Define the Shared Coefficient c
class SharedCoefficientLayer(tf.keras.layers.Layer):
    def __init__(self, size, initial_value=None, **kwargs):
        super(SharedCoefficientLayer, self).__init__(**kwargs)
        self.size = size
        self.initial_value = initial_value

    def build(self, input_shape):
        if self.initial_value is not None:
            initializer = tf.keras.initializers.Constant(self.initial_value)
        else:
            initializer = 'uniform'

        self.c = self.add_weight(name='c',
                                 shape=(self.size,),
                                 initializer=initializer,
                                 trainable=True)
        super(SharedCoefficientLayer, self).build(input_shape)

    def call(self, inputs):
        return self.c





# 3. Construct the Model with Shared Coefficients
import tensorflow as tf



def get_dimensions(matrix):
    rows = len(matrix)
    cols = len(matrix[0]) if rows > 0 else 0
    return (rows, cols)
# Modify the build_dual_polynomial_model function

# Add this function to your code
def high_temperature_sigmoid(x, k=5):
    return 1.0 / (1.0 + tf.exp(-k * x))

# Modify the DualPolynomialLayer to accept external coefficients
# Add this function to your code

# Modify the DualPolynomialLayer to accept external coefficients
class DualPolynomialLayerModified(tf.keras.layers.Layer):
    def __init__(self, power, h, **kwargs):
        super(DualPolynomialLayerModified, self).__init__(**kwargs)
        self.power = power
        self.h = tf.constant(h, dtype=tf.float32)  # Convert to a constant tensor

    def build(self, input_shape):
        self.breakx = self.add_weight(name='breakx',
                                      shape=(1,),
                                      initializer=tf.constant_initializer(value=250),trainable=True)

        self.breaky = self.add_weight(name='breaky',
                                      shape=(1,),
                                      initializer=tf.constant_initializer(value=0),
                                      trainable=True)
        super(DualPolynomialLayerModified, self).build(input_shape)

    def call(self, inputs, **kwargs):
        x, c = inputs

        # Calculate the polynomial terms for each power

        poly_terms = [tf.math.pow(x/(self.breakx), p) for p in self.power]
        poly_tensor = tf.stack(poly_terms, axis=-1)

        # Perform matrix multiplication with h and c
        output_terms = tf.matmul(poly_tensor, self.h)

        # Now, sum along the last dimension after multiplying with c
        poly_output = tf.reduce_sum(output_terms * c, axis=-1)

        # Apply the sigmoid-based conditioning
        sigmoid_term = high_temperature_sigmoid(x - self.breakx)
        outputs = (poly_output+self.breaky) * sigmoid_term + self.breaky * (1.0 - sigmoid_term)

        return outputs


def build_dual_polynomial_model(powers, h1, h2):
    # Ensure the powers argument contains the required sublists
    if 'powers1' not in powers or 'powers2' not in powers:
        raise ValueError("The 'powers' argument must contain 'powers1' and 'powers2' sublists.")

    # Create the model's input layers
    inputs1 = tf.keras.Input(shape=(1,), name='input_1')
    inputs2 = tf.keras.Input(shape=(1,), name='input_2')

    rowh1,colh1=get_dimensions(h1)
    rowh2,colh2=get_dimensions(h2)
    if colh1!=colh2:
        raise ValueError("Share C values dont match")


    # Shared coefficients layer
    initial_c_values = [0.5, 0.01]
    shared_c_layer = SharedCoefficientLayer(size=colh1, initial_value=initial_c_values, name="shared_coefficients_layer")
    shared_c = shared_c_layer(inputs1)
    # First polynomial layer with h1 matrix
    layer1 = DualPolynomialLayerModified(power=powers['powers1'], h=h1, name="dual_polynomial_1")
    outputs1 = layer1([inputs1, shared_c])

    # Second polynomial layer with h2 matrix
    layer2 = DualPolynomialLayerModified(power=powers['powers2'], h=h2, name="dual_polynomial_2")
    outputs2 = layer2([inputs2, shared_c])

    # Build and return the model
    model = tf.keras.Model(inputs=[inputs1, inputs2], outputs={'output_1': outputs1, 'output_2': outputs2})
    return model



# 4. Design the Combined Loss Function
# Assuming mean squared error for both, adjust as needed
def combined_loss(y_true, y_pred):
    #print("Shape of y_true:", tf.shape(y_true))
    #print("Shape of y_pred:", tf.shape(y_pred))

    loss1 = tf.keras.losses.MSE(y_true[0], y_pred[0])
    loss2 = tf.keras.losses.MSE(y_true[1], y_pred[1])
    return loss1 + loss2

#powers_dict = {'powers1': [1,-1,-3,-1], 'powers2': [-1, -2,-3,0]}
#powers_dict = {'powers1': [3,1,-1,1] 2 -1, 'powers2': [1, 0,-1,2]} 2 0 -2 0
powers_dict = {'powers1': [1,-2,-3,0], 'powers2': [1, -1,-3,-1]}
h_matrix1 = [[2, 0], [-2, 0], [0, -2],[0,2]]
h_matrix2 =[[2, 0], [-2, 0], [0,-2],[0,2] ]  # or any other matrix you'd like
model = build_dual_polynomial_model(powers_dict, h_matrix1, h_matrix2)

#https://en.wikipedia.org/wiki/Mooney%E2%80%93Rivlin_solid

# %%
m = len(x_datanocut)
n = len(x_datacut)

x_datacut_replicated = np.tile(x_datacut, m)
y_datacut_replicated = np.tile(y_datacut, m)

x_datanocut_replicated = np.tile(x_datanocut, n)
y_datanocut_replicated = np.tile(y_datanocut, n)

# Form a and b using reshaped data
a = [x_datacut_replicated.reshape((-1, 1)), x_datanocut_replicated.reshape((-1, 1))]
b = [y_datacut_replicated.reshape((-1, 1)), y_datanocut_replicated.reshape((-1, 1))]

# %%
# Set a custom learning rate
learning_rate = 1e-3

# Create the Adam optimizer with the custom learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, clipnorm=1.0)

# Compile the model with the custom optimizer
model.compile(optimizer=optimizer,
              loss={'output_1': 'mse', 'output_2': 'mse'},
              metrics={'output_1': 'mse', 'output_2': 'mse'})

# %%
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
a[0]

# %%
input_names = [input_layer.name.split(':')[0] for input_layer in model.inputs]

input_data_dict = {input_names[0]: a[0], input_names[1]: a[1]}
output_data_dict = {'output_1': b[0], 'output_2': b[1]}

history = model.fit(input_data_dict, output_data_dict, epochs=10000, batch_size=32)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9066 - dual_polynomial_2_loss: 4.7299 - dual_polynomial_1_mse: 0.9066 - dual_polynomial_2_mse: 4.7299
# Epoch 7502/10000
# 685/685 [==============================] - 4s 7ms/step - loss: 5.6366 - dual_polynomial_1_loss: 0.9090 - dual_polynomial_2_loss: 4.7276 - dual_polynomial_1_mse: 0.9090 - dual_polynomial_2_mse: 4.7276
# Epoch 7503/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9105 - dual_polynomial_2_loss: 4.7259 - dual_polynomial_1_mse: 0.9105 - dual_polynomial_2_mse: 4.7259
# Epoch 7504/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9022 - dual_polynomial_2_loss: 4.7342 - dual_polynomial_1_mse: 0.9022 - dual_polynomial_2_mse: 4.7342
# Epoch 7505/10000
# 685/685 [==============================] - 5s 7ms/step - loss: 5.6362 - dual_polynomial_1_loss: 0.9031 - dual_polynomial_2_loss: 4.7331 - dual_polynomial_1_mse: 0.9031 - dual_polynomial_2_mse: 4.7331
# Epoch 7506/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9094 - dual_polynomial_2_loss: 4.7270 - dual_polynomial_1_mse: 0.9094 - dual_polynomial_2_mse: 4.7270
# Epoch 7507/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9076 - dual_polynomial_2_loss: 4.7287 - dual_polynomial_1_mse: 0.9076 - dual_polynomial_2_mse: 4.7287
# Epoch 7508/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9099 - dual_polynomial_2_loss: 4.7264 - dual_polynomial_1_mse: 0.9099 - dual_polynomial_2_mse: 4.7264
# Epoch 7509/10000
# 685/685 [==============================] - 5s 7ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9099 - dual_polynomial_2_loss: 4.7264 - dual_polynomial_1_mse: 0.9099 - dual_polynomial_2_mse: 4.7264
# Epoch 7510/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9124 - dual_polynomial_2_loss: 4.7239 - dual_polynomial_1_mse: 0.9124 - dual_polynomial_2_mse: 4.7239
# Epoch 7511/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6366 - dual_polynomial_1_loss: 0.9102 - dual_polynomial_2_loss: 4.7265 - dual_polynomial_1_mse: 0.9102 - dual_polynomial_2_mse: 4.7265
# Epoch 7512/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6366 - dual_polynomial_1_loss: 0.9123 - dual_polynomial_2_loss: 4.7243 - dual_polynomial_1_mse: 0.9123 - dual_polynomial_2_mse: 4.7243
# Epoch 7513/10000
# 685/685 [==============================] - 5s 7ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9126 - dual_polynomial_2_loss: 4.7238 - dual_polynomial_1_mse: 0.9126 - dual_polynomial_2_mse: 4.7238
# Epoch 7514/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.
10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6365 - dual_polynomial_1_loss: 0.9060 - dual_polynomial_2_loss: 4.7305 - dual_polynomial_1_mse: 0.9060 - dual_polynomial_2_mse: 4.7305
# Epoch 9994/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6362 - dual_polynomial_1_loss: 0.9085 - dual_polynomial_2_loss: 4.7277 - dual_polynomial_1_mse: 0.9085 - dual_polynomial_2_mse: 4.7277
# Epoch 9995/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9098 - dual_polynomial_2_loss: 4.7265 - dual_polynomial_1_mse: 0.9098 - dual_polynomial_2_mse: 4.7265
# Epoch 9996/10000
# 685/685 [==============================] - 5s 7ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9011 - dual_polynomial_2_loss: 4.7352 - dual_polynomial_1_mse: 0.9011 - dual_polynomial_2_mse: 4.7352
# Epoch 9997/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9099 - dual_polynomial_2_loss: 4.7266 - dual_polynomial_1_mse: 0.9099 - dual_polynomial_2_mse: 4.7266
# Epoch 9998/10000
# 685/685 [==============================] - 4s 5ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9089 - dual_polynomial_2_loss: 4.7274 - dual_polynomial_1_mse: 0.9089 - dual_polynomial_2_mse: 4.7274
# Epoch 9999/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6364 - dual_polynomial_1_loss: 0.9081 - dual_polynomial_2_loss: 4.7283 - dual_polynomial_1_mse: 0.9081 - dual_polynomial_2_mse: 4.7283
# Epoch 10000/10000
# 685/685 [==============================] - 4s 6ms/step - loss: 5.6363 - dual_polynomial_1_loss: 0.9074 - dual_polynomial_2_loss: 4.7289 - dual_polynomial_1_mse: 0.9074 - dual_polynomial_2_mse: 4.7289

# %%
x_datanocut.shape

# %%
import matplotlib.pyplot as plt


def plot_predictions(model, x_datacut, y_datacut, x_datanocut, y_datanocut):
    # Create dummy data for each case (filled with zeros)
    dummy_data1 = np.zeros_like(x_datacut)
    dummy_data2 = np.zeros_like(x_datanocut)

    # Predict for x_datacut
    y_pred_datacut = model.predict([x_datacut, dummy_data1])['output_1']

    # Predict for x_datanocut
    y_pred_datanocut = model.predict([dummy_data2, x_datanocut])['output_2']

    # Plotting
    fig, ax = plt.subplots(2, 1, figsize=(12, 10))

    # Plot data for x_datacut
    ax[0].scatter(x_datacut, y_datacut, color='blue', label='Real')
    ax[0].scatter(x_datacut, y_pred_datacut, color='red', marker='x', label='Predicted')
    ax[0].set_title('x_datacut')
    ax[0].legend()

    # Plot data for x_datanocut
    ax[1].scatter(x_datanocut, y_datanocut, color='blue', label='Real')
    ax[1].scatter(x_datanocut, y_pred_datanocut, color='red', marker='x', label='Predicted')
    ax[1].set_title('x_datanocut')
    ax[1].legend()

    plt.tight_layout()
    plt.show()

# Assuming x_datacut, y_datacut, x_datanocut, and y_datanocut are defined
# Call the plot function
plot_predictions(model, x_datacut, y_datacut, x_datanocut, y_datanocut)
# Out:
# 9/9 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 5ms/step

# %%
shared_c_values = model.get_layer(name="shared_coefficients_layer").get_weights()[0]

# Extract breakx and breaky values for the first polynomial using its name
breakx1, breaky1 = model.get_layer(name="dual_polynomial_1").get_weights()

# Extract breakx and breaky values for the second polynomial using its name
breakx2, breaky2 = model.get_layer(name="dual_polynomial_2").get_weights()

print("Shared coefficients:", shared_c_values)

print("\nFirst Polynomial:")
print("breakx:", breakx1)
print("breaky:", breaky1)

print("\nSecond Polynomial:")
print("breakx:", breakx2)
print("breaky:", breaky2)
